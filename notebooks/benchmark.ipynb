# %%
# reload benchmark_ae   
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
from autoemulate.compare import AutoEmulate
from benchmark_ae.fetch_data import fetch_data
from autoemulate.utils import get_model_name

# %%
from pathlib import Path
path = Path('../data/')
paths = [path/'cardiac/cardiac{}/processed'.format(i) for i in range(1,13)]

# %% [markdown]
# # run autoemulate on all cardiac datasets

# %%
X, y = fetch_data(paths[0])
em = AutoEmulate()
em.setup(X, y)
em.models
# Out:
# [Pipeline(steps=[('scaler', StandardScaler()),
#                  ('model', SecondOrderPolynomial())]),
#  Pipeline(steps=[('scaler', StandardScaler()), ('model', RBF())]),
#  Pipeline(steps=[('scaler', StandardScaler()), ('model', RandomForest())]),
#  Pipeline(steps=[('scaler', StandardScaler()),
#                  ('model', MultiOutputRegressor(estimator=GradientBoosting()))]),
#  Pipeline(steps=[('scaler', StandardScaler()), ('model', GaussianProcessSk())]),
#  Pipeline(steps=[('scaler', StandardScaler()),
#                  ('model',
#                   MultiOutputRegressor(estimator=SupportVectorMachines()))]),
#  Pipeline(steps=[('scaler', StandardScaler()), ('model', NeuralNetSk())])]

# %%
def run_ae(path):
    print(f'Run AutoEmulate on {path}')
    X, y = fetch_data(path)
    em = AutoEmulate()
    em.setup(X, y, n_jobs=-2) # use_grid_search=True, grid_search_iters=10
    em.compare()
    best_model_name = get_model_name(em.best_model)
    cv_scores = em.scores_df
    cv_scores['path'] = str(path)
    cv_scores['best_model'] = best_model_name
    return cv_scores

# %%
datasets = [0,4,5,6,7]
paths_sub = [paths[i] for i in datasets]
paths_sub
# Out:
# [PosixPath('../data/cardiac/cardiac1/processed'),
#  PosixPath('../data/cardiac/cardiac5/processed'),
#  PosixPath('../data/cardiac/cardiac6/processed'),
#  PosixPath('../data/cardiac/cardiac7/processed'),
#  PosixPath('../data/cardiac/cardiac8/processed')]

# %%
# get paths 1, 5, 6, 7, 8
results_df = pd.concat([run_ae(path) for path in paths_sub])
# write to csv
results_df.to_csv('results_cardiac_nosearch_cardiac15678.csv', index=False)
# Out:
# autoemulate - Cross-validating SecondOrderPolynomial...
# autoemulate - Parameters: {'degree': 2}
# Run AutoEmulate on ../data/cardiac/cardiac1/processed
# autoemulate - Cross-validating RBF...
# autoemulate - Parameters: {'degree': 1, 'epsilon': 1.0, 'kernel': 'thin_plate_spline', 'smoothing': 0.0}
# autoemulate - Cross-validating RandomForest...
# autoemulate - Parameters: {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_samples': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100, 'oob_score': False, 'random_state': None}
# autoemulate - Cross-validating GradientBoosting...
# autoemulate - Parameters: {'estimator__ccp_alpha': 0.0, 'estimator__learning_rate': 0.1, 'estimator__loss': 'squared_error', 'estimator__max_depth': 3, 'estimator__max_features': None, 'estimator__min_samples_leaf': 1, 'estimator__min_samples_split': 2, 'estimator__n_estimators': 100, 'estimator__n_iter_no_change': None, 'estimator__random_state': None, 'estimator__subsample': 1.0, 'estimator': GradientBoosting(), 'n_jobs': None}
# autoemulate - Cross-validating GaussianProcessSk...
# autoemulate - Parameters: {'alpha': 1e-10, 'copy_X_train': True, 'kernel__length_scale': 1.0, 'kernel__length_scale_bounds': (1e-05, 100000.0), 'kernel': RBF(length_scale=1), 'n_restarts_optimizer': 20, 'normalize_y': True, 'optimizer': 'fmin_l_bfgs_b', 'random_state': None}
# autoemulate - Cross-validating SupportVectorMachines...
# autoemulate - Parameters: {'estimator__C': 1.0, 'estimator__cache_size': 200, 'estimator__coef0': 0.0, 'estimator__degree': 3, 'estimator__epsilon': 0.1, 'estimator__gamma': 'scale', 'estimator__kernel': 'rbf', 'estimator__max_iter': -1, 'estimator__normalise_y': True, 'estimator__shrinking': True, 'estimator__tol': 0.001, 'estimator__verbose': False, 'estimator': SupportVectorMachines(), 'n_jobs': None}
# autoemulate - Cross-validating NeuralNetSk...
# autoemulate - Parameters: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_iter': 200, 'random_state': None, 'solver': 'adam', 'tol': 0.0001}
# autoemulate - GaussianProcessSk is the best model with r2 = 0.995.
# autoemulate - Cross-validating SecondOrderPolynomial...
# autoemulate - Parameters: {'degree': 2}
# autoemulate - Cross-validating RBF...
# autoemulate - Parameters: {'degree': 1, 'epsilon': 1.0, 'kernel': 'thin_plate_spline', 'smoothing': 0.0}
# autoemulate - Cross-validating RandomForest...
# autoemulate - Parameters: {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_samples': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100, 'oob_score': False, 'random_state': None}
# Run AutoEmulate on ../data/cardiac/cardiac5/processed
# autoemulate - Cross-validating GradientBoosting...
# autoemulate - Parameters: {'estimator__ccp_alpha': 0.0, 'estimator__learning_rate': 0.1, 'estimator__loss': 'squared_error', 'estimator__max_depth': 3, 'estimator__max_features': None, 'estimator__min_samples_leaf': 1, 'estimator__min_samples_split': 2, 'estimator__n_estimators': 100, 'estimator__n_iter_no_change': None, 'estimator__random_state': None, 'estimator__subsample': 1.0, 'estimator': GradientBoosting(), 'n_jobs': None}
# autoemulate - Cross-validating GaussianProcessSk...
# autoemulate - Parameters: {'alpha': 1e-10, 'copy_X_train': True, 'kernel__length_scale': 1.0, 'kernel__length_scale_bounds': (1e-05, 100000.0), 'kernel': RBF(length_scale=1), 'n_restarts_optimizer': 20, 'normalize_y': True, 'optimizer': 'fmin_l_bfgs_b', 'random_state': None}
# autoemulate - Cross-validating SupportVectorMachines...
# autoemulate - Parameters: {'estimator__C': 1.0, 'estimator__cache_size': 200, 'estimator__coef0': 0.0, 'estimator__degree': 3, 'estimator__epsilon': 0.1, 'estimator__gamma': 'scale', 'estimator__kernel': 'rbf', 'estimator__max_iter': -1, 'estimator__normalise_y': True, 'estimator__shrinking': True, 'estimator__tol': 0.001, 'estimator__verbose': False, 'estimator': SupportVectorMachines(), 'n_jobs': None}
# autoemulate - Cross-validating NeuralNetSk...
# autoemulate - Parameters: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_iter': 200, 'random_state': None, 'solver': 'adam', 'tol': 0.0001}
# autoemulate - SecondOrderPolynomial is the best model with r2 = 0.973.
# autoemulate - Cross-validating SecondOrderPolynomial...
# autoemulate - Parameters: {'degree': 2}
# autoemulate - Cross-validating RBF...
# autoemulate - Parameters: {'degree': 1, 'epsilon': 1.0, 'kernel': 'thin_plate_spline', 'smoothing': 0.0}
# autoemulate - Cross-validating RandomForest...
# autoemulate - Parameters: {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_samples': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100, 'oob_score': False, 'random_state': None}
# Run AutoEmulate on ../data/cardiac/cardiac6/processed
# autoemulate - Cross-validating GradientBoosting...
# autoemulate - Parameters: {'estimator__ccp_alpha': 0.0, 'estimator__learning_rate': 0.1, 'estimator__loss': 'squared_error', 'estimator__max_depth': 3, 'estimator__max_features': None, 'estimator__min_samples_leaf': 1, 'estimator__min_samples_split': 2, 'estimator__n_estimators': 100, 'estimator__n_iter_no_change': None, 'estimator__random_state': None, 'estimator__subsample': 1.0, 'estimator': GradientBoosting(), 'n_jobs': None}
# autoemulate - Cross-validating GaussianProcessSk...
# autoemulate - Parameters: {'alpha': 1e-10, 'copy_X_train': True, 'kernel__length_scale': 1.0, 'kernel__length_scale_bounds': (1e-05, 100000.0), 'kernel': RBF(length_scale=1), 'n_restarts_optimizer': 20, 'normalize_y': True, 'optimizer': 'fmin_l_bfgs_b', 'random_state': None}
# autoemulate - Cross-validating SupportVectorMachines...
# autoemulate - Parameters: {'estimator__C': 1.0, 'estimator__cache_size': 200, 'estimator__coef0': 0.0, 'estimator__degree': 3, 'estimator__epsilon': 0.1, 'estimator__gamma': 'scale', 'estimator__kernel': 'rbf', 'estimator__max_iter': -1, 'estimator__normalise_y': True, 'estimator__shrinking': True, 'estimator__tol': 0.001, 'estimator__verbose': False, 'estimator': SupportVectorMachines(), 'n_jobs': None}
# autoemulate - Cross-validating NeuralNetSk...
# autoemulate - Parameters: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_iter': 200, 'random_state': None, 'solver': 'adam', 'tol': 0.0001}
# autoemulate - RBF is the best model with r2 = 0.875.
# autoemulate - Cross-validating SecondOrderPolynomial...
# autoemulate - Parameters: {'degree': 2}
# autoemulate - Cross-validating RBF...
# autoemulate - Parameters: {'degree': 1, 'epsilon': 1.0, 'kernel': 'thin_plate_spline', 'smoothing': 0.0}
# autoemulate - Cross-validating RandomForest...
# autoemulate - Parameters: {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_samples': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100, 'oob_score': False, 'random_state': None}
# Run AutoEmulate on ../data/cardiac/cardiac7/processed
# autoemulate - Cross-validating GradientBoosting...
# autoemulate - Parameters: {'estimator__ccp_alpha': 0.0, 'estimator__learning_rate': 0.1, 'estimator__loss': 'squared_error', 'estimator__max_depth': 3, 'estimator__max_features': None, 'estimator__min_samples_leaf': 1, 'estimator__min_samples_split': 2, 'estimator__n_estimators': 100, 'estimator__n_iter_no_change': None, 'estimator__random_state': None, 'estimator__subsample': 1.0, 'estimator': GradientBoosting(), 'n_jobs': None}
# autoemulate - Cross-validating GaussianProcessSk...
# autoemulate - Parameters: {'alpha': 1e-10, 'copy_X_train': True, 'kernel__length_scale': 1.0, 'kernel__length_scale_bounds': (1e-05, 100000.0), 'kernel': RBF(length_scale=1), 'n_restarts_optimizer': 20, 'normalize_y': True, 'optimizer': 'fmin_l_bfgs_b', 'random_state': None}
# autoemulate - Cross-validating SupportVectorMachines...
# autoemulate - Parameters: {'estimator__C': 1.0, 'estimator__cache_size': 200, 'estimator__coef0': 0.0, 'estimator__degree': 3, 'estimator__epsilon': 0.1, 'estimator__gamma': 'scale', 'estimator__kernel': 'rbf', 'estimator__max_iter': -1, 'estimator__normalise_y': True, 'estimator__shrinking': True, 'estimator__tol': 0.001, 'estimator__verbose': False, 'estimator': SupportVectorMachines(), 'n_jobs': None}
# autoemulate - Cross-validating NeuralNetSk...
# autoemulate - Parameters: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_iter': 200, 'random_state': None, 'solver': 'adam', 'tol': 0.0001}
# autoemulate - SecondOrderPolynomial is the best model with r2 = 0.940.
# autoemulate - Cross-validating SecondOrderPolynomial...
# autoemulate - Parameters: {'degree': 2}
# autoemulate - Cross-validating RBF...
# autoemulate - Parameters: {'degree': 1, 'epsilon': 1.0, 'kernel': 'thin_plate_spline', 'smoothing': 0.0}
# autoemulate - Cross-validating RandomForest...
# autoemulate - Parameters: {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_samples': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100, 'oob_score': False, 'random_state': None}
# Run AutoEmulate on ../data/cardiac/cardiac8/processed
# autoemulate - Cross-validating GradientBoosting...
# autoemulate - Parameters: {'estimator__ccp_alpha': 0.0, 'estimator__learning_rate': 0.1, 'estimator__loss': 'squared_error', 'estimator__max_depth': 3, 'estimator__max_features': None, 'estimator__min_samples_leaf': 1, 'estimator__min_samples_split': 2, 'estimator__n_estimators': 100, 'estimator__n_iter_no_change': None, 'estimator__random_state': None, 'estimator__subsample': 1.0, 'estimator': GradientBoosting(), 'n_jobs': None}
# autoemulate - Cross-validating GaussianProcessSk...
# autoemulate - Parameters: {'alpha': 1e-10, 'copy_X_train': True, 'kernel__length_scale': 1.0, 'kernel__length_scale_bounds': (1e-05, 100000.0), 'kernel': RBF(length_scale=1), 'n_restarts_optimizer': 20, 'normalize_y': True, 'optimizer': 'fmin_l_bfgs_b', 'random_state': None}
# autoemulate - Cross-validating SupportVectorMachines...
# autoemulate - Parameters: {'estimator__C': 1.0, 'estimator__cache_size': 200, 'estimator__coef0': 0.0, 'estimator__degree': 3, 'estimator__epsilon': 0.1, 'estimator__gamma': 'scale', 'estimator__kernel': 'rbf', 'estimator__max_iter': -1, 'estimator__normalise_y': True, 'estimator__shrinking': True, 'estimator__tol': 0.001, 'estimator__verbose': False, 'estimator': SupportVectorMachines(), 'n_jobs': None}
# autoemulate - Cross-validating NeuralNetSk...
# autoemulate - Parameters: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_iter': 200, 'random_state': None, 'solver': 'adam', 'tol': 0.0001}
# autoemulate - RBF is the best model with r2 = 0.987.

# %%
results_df
# Out:
#                     model metric  fold     score  \
# 0   SecondOrderPolynomial   rsme     0  1.214096
# 1   SecondOrderPolynomial   rsme     1  1.834830
# 2   SecondOrderPolynomial   rsme     2  1.210832
# 3   SecondOrderPolynomial   rsme     3  1.204286
# 4   SecondOrderPolynomial   rsme     4  1.354231
# ..                    ...    ...   ...       ...
# 75            NeuralNetSk     r2     0  0.156044
# 76            NeuralNetSk     r2     1 -0.005696
# 77            NeuralNetSk     r2     2 -0.015550
# 78            NeuralNetSk     r2     3  0.021491
# 79            NeuralNetSk     r2     4  0.222311
#
#                                   path             best_model
# 0   ../data/cardiac/cardiac1/processed                    RBF
# 1   ../data/cardiac/cardiac1/processed                    RBF
# 2   ../data/cardiac/cardiac1/processed                    RBF
# 3   ../data/cardiac/cardiac1/processed                    RBF
# 4   ../data/cardiac/cardiac1/processed                    RBF
# ..                                 ...                    ...
# 75  ../data/cardiac/cardiac2/processed  SecondOrderPolynomial
# 76  ../data/cardiac/cardiac2/processed  SecondOrderPolynomial
# 77  ../data/cardiac/cardiac2/processed  SecondOrderPolynomial
# 78  ../data/cardiac/cardiac2/processed  SecondOrderPolynomial
# 79  ../data/cardiac/cardiac2/processed  SecondOrderPolynomial
#
# [160 rows x 6 columns]

# %%
# mapping from cardiac to descriptive

cardiac_descriptions = {
    "cardiac1": "Atrial Ionic",
    "cardiac2": "Atrial Isotonic Contraction",
    "cardiac3": "Atrial Isometric Stretch 1.0",
    "cardiac4": "Atrial Isometric Stretch 1.1",
    "cardiac5": "CircAdap",
    "cardiac6": "Fourchamber Model",
    "cardiac7": "Passive Mechanics",
    "cardiac8": "Tissue Electrophysiology",
    "cardiac9": "Ventricular Ionic",
    "cardiac10": "Ventricular Isotonic Contraction",
    "cardiac11": "Ventricular Isometric Stretch 1.0",
    "cardiac12": "Ventricular Isometric Stretch 1.1"
}

# %%
(results_df
    # filter out mteric = rsme
    .query('metric != "rsme"')
    .groupby(['path', 'metric', 'model'])
    .agg({'score': ['mean', 'std']})
    # sort by mean score for each path
    .sort_values(by=['path', ('score', 'mean')], ascending=False)
    # sort path from cardiac1 to cardiac12
    .sort_index(level=0, sort_remaining=False)
    .reset_index()
    # Extract cardiac number and create a new column
    .assign(cardiac=lambda df: df['path'].str.extract('(cardiac\d+)')[0])
)
# Out:
#                                   path metric                  model  \
#
# 0   ../data/cardiac/cardiac1/processed     r2                    RBF
# 1   ../data/cardiac/cardiac1/processed     r2      GaussianProcessSk
# 2   ../data/cardiac/cardiac1/processed     r2  SecondOrderPolynomial
# 3   ../data/cardiac/cardiac1/processed     r2  SupportVectorMachines
# 4   ../data/cardiac/cardiac1/processed     r2       GradientBoosting
# 5   ../data/cardiac/cardiac1/processed     r2                XGBoost
# 6   ../data/cardiac/cardiac1/processed     r2           RandomForest
# 7   ../data/cardiac/cardiac1/processed     r2            NeuralNetSk
# 8   ../data/cardiac/cardiac2/processed     r2  SecondOrderPolynomial
# 9   ../data/cardiac/cardiac2/processed     r2                    RBF
# 10  ../data/cardiac/cardiac2/processed     r2  SupportVectorMachines
# 11  ../data/cardiac/cardiac2/processed     r2       GradientBoosting
# 12  ../data/cardiac/cardiac2/processed     r2                XGBoost
# 13  ../data/cardiac/cardiac2/processed     r2      GaussianProcessSk
# 14  ../data/cardiac/cardiac2/processed     r2           RandomForest
# 15  ../data/cardiac/cardiac2/processed     r2            NeuralNetSk
#
#          score              cardiac
#           mean        std
# 0     0.994564   0.001094  cardiac1
# 1     0.994522   0.000366  cardiac1
# 2     0.994057   0.001043  cardiac1
# 3     0.952853   0.008369  cardiac1
# 4     0.920941   0.006775  cardiac1
# 5     0.891877   0.015081  cardiac1
# 6     0.655266   0.018354  cardiac1
# 7  -156.020665  39.703207  cardiac1
# 8     0.834925   0.010954  cardiac2
# 9     0.818380   0.014362  cardiac2
# 10    0.753703   0.005290  cardiac2
# 11    0.661940   0.015846  cardiac2
# 12    0.650019   0.009549  cardiac2
# 13    0.453594   0.361179  cardiac2
# 14    0.420178   0.012334  cardiac2
# 15    0.075720   0.107052  cardiac2

# %%
# Out:
# {'RBF':                     model metric  fold       score
#  0   SecondOrderPolynomial   rsme     0    1.658468
#  1   SecondOrderPolynomial   rsme     1    1.550802
#  2   SecondOrderPolynomial   rsme     2    1.276326
#  3   SecondOrderPolynomial   rsme     3    1.059498
#  4   SecondOrderPolynomial   rsme     4    1.224820
#  ..                    ...    ...   ...         ...
#  75            NeuralNetSk     r2     0 -110.597701
#  76            NeuralNetSk     r2     1 -118.794065
#  77            NeuralNetSk     r2     2 -127.591954
#  78            NeuralNetSk     r2     3 -155.855949
#  79            NeuralNetSk     r2     4 -184.621297
#
#  [80 rows x 4 columns]}

# %%
# load csv as numpy array
X,y = fetch_data(path/'cardiac/cardiac1/processed')

# %%
em = AutoEmulate()
em.setup(X, y, n_jobs=-1, grid_search_iters=50, folds=5, grid_search_type='random')
em.compare()
# Out:
# autoemulate - Cross-validating SecondOrderPolynomial...
# autoemulate - Parameters: {'degree': 2}
# autoemulate - Cross-validating RBF...
# autoemulate - Parameters: {'degree': 1, 'epsilon': 1.0, 'kernel': 'thin_plate_spline', 'smoothing': 0.0}
# autoemulate - Cross-validating RandomForest...
# autoemulate - Parameters: {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_samples': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100, 'oob_score': False, 'random_state': None}
# autoemulate - Cross-validating GradientBoosting...
# autoemulate - Parameters: {'estimator__ccp_alpha': 0.0, 'estimator__learning_rate': 0.1, 'estimator__loss': 'squared_error', 'estimator__max_depth': 3, 'estimator__max_features': None, 'estimator__min_samples_leaf': 1, 'estimator__min_samples_split': 2, 'estimator__n_estimators': 100, 'estimator__n_iter_no_change': None, 'estimator__random_state': None, 'estimator__subsample': 1.0, 'estimator': GradientBoosting(), 'n_jobs': None}
# autoemulate - Cross-validating GaussianProcessSk...
# autoemulate - Parameters: {'alpha': 1e-10, 'copy_X_train': True, 'kernel__length_scale': 1.0, 'kernel__length_scale_bounds': (1e-05, 100000.0), 'kernel': RBF(length_scale=1), 'n_restarts_optimizer': 20, 'normalize_y': True, 'optimizer': 'fmin_l_bfgs_b', 'random_state': None}
# autoemulate - Cross-validating SupportVectorMachines...
# autoemulate - Parameters: {'estimator__C': 1.0, 'estimator__cache_size': 200, 'estimator__coef0': 0.0, 'estimator__degree': 3, 'estimator__epsilon': 0.1, 'estimator__gamma': 'scale', 'estimator__kernel': 'rbf', 'estimator__max_iter': -1, 'estimator__normalise_y': True, 'estimator__shrinking': True, 'estimator__tol': 0.001, 'estimator__verbose': False, 'estimator': SupportVectorMachines(), 'n_jobs': None}
# autoemulate - Cross-validating XGBoost...
# autoemulate - Parameters: {'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 1, 'gamma': 0, 'learning_rate': 0.3, 'max_delta_step': 0, 'max_depth': 6, 'max_leaves': 0, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': None, 'objective': 'reg:squarederror', 'random_state': None, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 1, 'tree_method': 'auto', 'verbosity': 0}
# autoemulate - Cross-validating NeuralNetSk...
# autoemulate - Parameters: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_iter': 200, 'random_state': None, 'solver': 'adam', 'tol': 0.0001}
# autoemulate - RBF is the best model with r2 = 0.994.
# Pipeline(steps=[('scaler', StandardScaler()), ('model', RBF())])

# %%
em.scores_df
# Out:
#                     model metric  fold       score
# 0   SecondOrderPolynomial   rsme     0    1.148593
# 1   SecondOrderPolynomial   rsme     1    2.113252
# 2   SecondOrderPolynomial   rsme     2    1.335141
# 3   SecondOrderPolynomial   rsme     3    1.041811
# 4   SecondOrderPolynomial   rsme     4    1.229983
# ..                    ...    ...   ...         ...
# 75            NeuralNetSk     r2     0 -125.558727
# 76            NeuralNetSk     r2     1 -113.039760
# 77            NeuralNetSk     r2     2 -108.484559
# 78            NeuralNetSk     r2     3 -148.870362
# 79            NeuralNetSk     r2     4 -137.387880
#
# [80 rows x 4 columns]
