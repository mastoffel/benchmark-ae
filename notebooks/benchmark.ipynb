# %%
# reload benchmark_ae   
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
from autoemulate.compare import AutoEmulate
from benchmark_ae.fetch_data import fetch_data
from autoemulate.utils import get_model_name

# %%
from pathlib import Path
path = Path('../data/')
paths = [path/'cardiac/cardiac{}/processed'.format(i) for i in range(1,13)]

# %% [markdown]
# # run autoemulate on all cardiac datasets

# %%
def run_ae(path):
    print(f'Run AutoEmulate on {path}')
    X, y = fetch_data(path)
    em = AutoEmulate()
    em.setup(X, y, n_jobs=-2) # use_grid_search=True, grid_search_iters=10
    em.compare()
    best_model_name = get_model_name(em.best_model)
    cv_scores = em.scores_df
    cv_scores['path'] = str(path)
    cv_scores['best_model'] = best_model_name
    return cv_scores

# %%
datasets = [0,4,5,6,7]
paths_sub = [paths[i] for i in datasets]
paths_sub
# Out:
# [PosixPath('../data/cardiac/cardiac1/processed'),
#  PosixPath('../data/cardiac/cardiac5/processed'),
#  PosixPath('../data/cardiac/cardiac6/processed'),
#  PosixPath('../data/cardiac/cardiac7/processed'),
#  PosixPath('../data/cardiac/cardiac8/processed')]

# %%
# get paths 1, 5, 6, 7, 8
results_df = pd.concat([run_ae(path) for path in paths_sub])
# write to csv
results_df.to_csv('results_cardiac_random_10_cardiac15678.csv', index=False)
# Out:
# autoemulate - Performing grid search for SecondOrderPolynomial...
# Run AutoEmulate on ../data/cardiac/cardiac1/processed
# autoemulate - Best parameters for SecondOrderPolynomial: {}
# autoemulate - Cross-validating SecondOrderPolynomial...
# autoemulate - Parameters: {'degree': 2}
# autoemulate - Performing grid search for RBF...
# autoemulate - Best parameters for RBF: {'model__degree': 2, 'model__kernel': 'quintic', 'model__smoothing': 0.5483261350952312}
# autoemulate - Cross-validating RBF...
# autoemulate - Parameters: {'degree': 2, 'epsilon': 1.0, 'kernel': 'quintic', 'smoothing': 0.5483261350952312}
# autoemulate - Performing grid search for RandomForest...
# autoemulate - Best parameters for RandomForest: {'model__bootstrap': True, 'model__max_features': 'sqrt', 'model__max_samples': None, 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 332, 'model__oob_score': False}
# autoemulate - Cross-validating RandomForest...
# autoemulate - Parameters: {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 'sqrt', 'max_samples': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 332, 'oob_score': False, 'random_state': None}
# autoemulate - Performing grid search for GradientBoosting...
# autoemulate - Best parameters for GradientBoosting: {'model__estimator__ccp_alpha': 0.015337386171203593, 'model__estimator__learning_rate': 0.04829061583712451, 'model__estimator__max_depth': 4, 'model__estimator__max_features': None, 'model__estimator__min_samples_leaf': 5, 'model__estimator__min_samples_split': 7, 'model__estimator__n_estimators': 243, 'model__estimator__subsample': 0.9648970536948694}
# autoemulate - Cross-validating GradientBoosting...
# autoemulate - Parameters: {'estimator__ccp_alpha': 0.015337386171203593, 'estimator__learning_rate': 0.04829061583712451, 'estimator__loss': 'squared_error', 'estimator__max_depth': 4, 'estimator__max_features': None, 'estimator__min_samples_leaf': 5, 'estimator__min_samples_split': 7, 'estimator__n_estimators': 243, 'estimator__n_iter_no_change': None, 'estimator__random_state': None, 'estimator__subsample': 0.9648970536948694, 'estimator': GradientBoosting(ccp_alpha=0.015337386171203593,
#                  learning_rate=0.04829061583712451, max_depth=4,
#                  min_samples_leaf=5, min_samples_split=7, n_estimators=243,
#                  subsample=0.9648970536948694), 'n_jobs': None}
# autoemulate - Performing grid search for GaussianProcessSk...
# autoemulate - Best parameters for GaussianProcessSk: {'model__alpha': 4.37105550313462e-09, 'model__kernel': RationalQuadratic(alpha=1, length_scale=1), 'model__normalize_y': True, 'model__optimizer': 'fmin_l_bfgs_b'}
# autoemulate - Cross-validating GaussianProcessSk...
# autoemulate - Parameters: {'alpha': 4.37105550313462e-09, 'copy_X_train': True, 'kernel__length_scale': 1.0, 'kernel__alpha': 1.0, 'kernel__length_scale_bounds': (1e-05, 100000.0), 'kernel__alpha_bounds': (1e-05, 100000.0), 'kernel': RationalQuadratic(alpha=1, length_scale=1), 'n_restarts_optimizer': 20, 'normalize_y': True, 'optimizer': 'fmin_l_bfgs_b', 'random_state': None}
# autoemulate - Performing grid search for SupportVectorMachines...
# autoemulate - Best parameters for SupportVectorMachines: {'model__estimator__C': 3.2178811502333913, 'model__estimator__cache_size': 364, 'model__estimator__coef0': 0.6395534078098084, 'model__estimator__degree': 2, 'model__estimator__epsilon': 0.2201514418219762, 'model__estimator__gamma': 'auto', 'model__estimator__kernel': 'poly', 'model__estimator__max_iter': -1, 'model__estimator__shrinking': False, 'model__estimator__tol': 0.0007775165575447761, 'model__estimator__verbose': False}
# autoemulate - Cross-validating SupportVectorMachines...
# autoemulate - Parameters: {'estimator__C': 3.2178811502333913, 'estimator__cache_size': 364, 'estimator__coef0': 0.6395534078098084, 'estimator__degree': 2, 'estimator__epsilon': 0.2201514418219762, 'estimator__gamma': 'auto', 'estimator__kernel': 'poly', 'estimator__max_iter': -1, 'estimator__normalise_y': True, 'estimator__shrinking': False, 'estimator__tol': 0.0007775165575447761, 'estimator__verbose': False, 'estimator': SupportVectorMachines(C=3.2178811502333913, cache_size=364,
#                       coef0=0.6395534078098084, degree=2,
#                       epsilon=0.2201514418219762, gamma='auto', kernel='poly',
#                       shrinking=False, tol=0.0007775165575447761), 'n_jobs': None}
# autoemulate - Performing grid search for NeuralNetSk...
# autoemulate - Best parameters for NeuralNetSk: {'model__activation': 'relu', 'model__alpha': 0.026633271175031524, 'model__hidden_layer_sizes': (50,), 'model__learning_rate_init': 0.00012550429463946468, 'model__solver': 'lbfgs'}
# autoemulate - Cross-validating NeuralNetSk...
# autoemulate - Parameters: {'activation': 'relu', 'alpha': 0.026633271175031524, 'hidden_layer_sizes': (50,), 'learning_rate': 'constant', 'learning_rate_init': 0.00012550429463946468, 'max_iter': 200, 'random_state': None, 'solver': 'lbfgs', 'tol': 0.0001}
# autoemulate - RBF is the best model with r2 = 0.996.
# autoemulate - Performing grid search for SecondOrderPolynomial...
# autoemulate - Best parameters for SecondOrderPolynomial: {}
# autoemulate - Cross-validating SecondOrderPolynomial...
# autoemulate - Parameters: {'degree': 2}
# Run AutoEmulate on ../data/cardiac/cardiac5/processed
# autoemulate - Performing grid search for RBF...
# autoemulate - Best parameters for RBF: {'model__degree': 2, 'model__kernel': 'gaussian', 'model__smoothing': 0.616111094590473}
# autoemulate - Cross-validating RBF...
# autoemulate - Parameters: {'degree': 2, 'epsilon': 1.0, 'kernel': 'gaussian', 'smoothing': 0.616111094590473}
# autoemulate - Performing grid search for RandomForest...
# autoemulate - Best parameters for RandomForest: {'model__bootstrap': False, 'model__max_features': 'sqrt', 'model__max_samples': 0.5, 'model__min_samples_leaf': 2, 'model__min_samples_split': 10, 'model__n_estimators': 396, 'model__oob_score': True}
# autoemulate - Cross-validating RandomForest...
# autoemulate - Parameters: {'bootstrap': False, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 'sqrt', 'max_samples': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 396, 'oob_score': True, 'random_state': None}
# autoemulate - Performing grid search for GradientBoosting...
# autoemulate - Best parameters for GradientBoosting: {'model__estimator__ccp_alpha': 0.048890254216946816, 'model__estimator__learning_rate': 0.15152953379736123, 'model__estimator__max_depth': 3, 'model__estimator__max_features': None, 'model__estimator__min_samples_leaf': 4, 'model__estimator__min_samples_split': 5, 'model__estimator__n_estimators': 296, 'model__estimator__subsample': 0.659641244385189}
# autoemulate - Cross-validating GradientBoosting...
# autoemulate - Parameters: {'estimator__ccp_alpha': 0.048890254216946816, 'estimator__learning_rate': 0.15152953379736123, 'estimator__loss': 'squared_error', 'estimator__max_depth': 3, 'estimator__max_features': None, 'estimator__min_samples_leaf': 4, 'estimator__min_samples_split': 5, 'estimator__n_estimators': 296, 'estimator__n_iter_no_change': None, 'estimator__random_state': None, 'estimator__subsample': 0.659641244385189, 'estimator': GradientBoosting(ccp_alpha=0.048890254216946816,
#                  learning_rate=0.15152953379736123, min_samples_leaf=4,
#                  min_samples_split=5, n_estimators=296,
#                  subsample=0.659641244385189), 'n_jobs': None}
# autoemulate - Performing grid search for GaussianProcessSk...
# autoemulate - Best parameters for GaussianProcessSk: {'model__alpha': 0.008837420535817448, 'model__kernel': RationalQuadratic(alpha=1, length_scale=1), 'model__normalize_y': True, 'model__optimizer': 'fmin_l_bfgs_b'}
# autoemulate - Cross-validating GaussianProcessSk...
# autoemulate - Parameters: {'alpha': 0.008837420535817448, 'copy_X_train': True, 'kernel__length_scale': 1.0, 'kernel__alpha': 1.0, 'kernel__length_scale_bounds': (1e-05, 100000.0), 'kernel__alpha_bounds': (1e-05, 100000.0), 'kernel': RationalQuadratic(alpha=1, length_scale=1), 'n_restarts_optimizer': 20, 'normalize_y': True, 'optimizer': 'fmin_l_bfgs_b', 'random_state': None}
# autoemulate - Performing grid search for SupportVectorMachines...
# autoemulate - Best parameters for SupportVectorMachines: {'model__estimator__C': 1.3874342421518642, 'model__estimator__cache_size': 282, 'model__estimator__coef0': 0.9303724962567121, 'model__estimator__degree': 2, 'model__estimator__epsilon': 0.26753781316150865, 'model__estimator__gamma': 'auto', 'model__estimator__kernel': 'poly', 'model__estimator__max_iter': -1, 'model__estimator__shrinking': False, 'model__estimator__tol': 0.00010276192574988106, 'model__estimator__verbose': False}
# autoemulate - Cross-validating SupportVectorMachines...
# autoemulate - Parameters: {'estimator__C': 1.3874342421518642, 'estimator__cache_size': 282, 'estimator__coef0': 0.9303724962567121, 'estimator__degree': 2, 'estimator__epsilon': 0.26753781316150865, 'estimator__gamma': 'auto', 'estimator__kernel': 'poly', 'estimator__max_iter': -1, 'estimator__normalise_y': True, 'estimator__shrinking': False, 'estimator__tol': 0.00010276192574988106, 'estimator__verbose': False, 'estimator': SupportVectorMachines(C=1.3874342421518642, cache_size=282,
#                       coef0=0.9303724962567121, degree=2,
#                       epsilon=0.26753781316150865, gamma='auto', kernel='poly',
#                       shrinking=False, tol=0.00010276192574988106), 'n_jobs': None}
# autoemulate - Performing grid search for NeuralNetSk...
# autoemulate - Best parameters for NeuralNetSk: {'model__activation': 'relu', 'model__alpha': 0.0030583989601681836, 'model__hidden_layer_sizes': (50,), 'model__learning_rate_init': 0.0019114400005343258, 'model__solver': 'lbfgs'}
# autoemulate - Cross-validating NeuralNetSk...
# autoemulate - Parameters: {'activation': 'relu', 'alpha': 0.0030583989601681836, 'hidden_layer_sizes': (50,), 'learning_rate': 'constant', 'learning_rate_init': 0.0019114400005343258, 'max_iter': 200, 'random_state': None, 'solver': 'lbfgs', 'tol': 0.0001}
# autoemulate - SecondOrderPolynomial is the best model with r2 = 0.974.
# autoemulate - Performing grid search for SecondOrderPolynomial...
# Run AutoEmulate on ../data/cardiac/cardiac6/processed
# autoemulate - Best parameters for SecondOrderPolynomial: {}
# autoemulate - Cross-validating SecondOrderPolynomial...
# autoemulate - Parameters: {'degree': 2}
# autoemulate - Performing grid search for RBF...
# autoemulate - Best parameters for RBF: {'model__degree': 1, 'model__kernel': 'gaussian', 'model__smoothing': 0.48674118881262574}
# autoemulate - Cross-validating RBF...
# autoemulate - Parameters: {'degree': 1, 'epsilon': 1.0, 'kernel': 'gaussian', 'smoothing': 0.48674118881262574}
# autoemulate - Performing grid search for RandomForest...
# autoemulate - Best parameters for RandomForest: {'model__bootstrap': True, 'model__max_features': None, 'model__max_samples': 0.5, 'model__min_samples_leaf': 9, 'model__min_samples_split': 7, 'model__n_estimators': 407, 'model__oob_score': False}
# autoemulate - Cross-validating RandomForest...
# autoemulate - Parameters: {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': None, 'max_features': None, 'max_samples': 0.5, 'min_samples_leaf': 9, 'min_samples_split': 7, 'n_estimators': 407, 'oob_score': False, 'random_state': None}
# autoemulate - Performing grid search for GradientBoosting...
# autoemulate - Best parameters for GradientBoosting: {'model__estimator__ccp_alpha': 0.012492341753762733, 'model__estimator__learning_rate': 0.0569288709987473, 'model__estimator__max_depth': 4, 'model__estimator__max_features': None, 'model__estimator__min_samples_leaf': 4, 'model__estimator__min_samples_split': 19, 'model__estimator__n_estimators': 397, 'model__estimator__subsample': 0.6074419269454944}
# autoemulate - Cross-validating GradientBoosting...
# autoemulate - Parameters: {'estimator__ccp_alpha': 0.012492341753762733, 'estimator__learning_rate': 0.0569288709987473, 'estimator__loss': 'squared_error', 'estimator__max_depth': 4, 'estimator__max_features': None, 'estimator__min_samples_leaf': 4, 'estimator__min_samples_split': 19, 'estimator__n_estimators': 397, 'estimator__n_iter_no_change': None, 'estimator__random_state': None, 'estimator__subsample': 0.6074419269454944, 'estimator': GradientBoosting(ccp_alpha=0.012492341753762733,
#                  learning_rate=0.0569288709987473, max_depth=4,
#                  min_samples_leaf=4, min_samples_split=19, n_estimators=397,
#                  subsample=0.6074419269454944), 'n_jobs': None}
# autoemulate - Performing grid search for GaussianProcessSk...
# autoemulate - Best parameters for GaussianProcessSk: {'model__alpha': 0.005488825696304717, 'model__kernel': RationalQuadratic(alpha=1, length_scale=1), 'model__normalize_y': True, 'model__optimizer': 'fmin_l_bfgs_b'}
# autoemulate - Cross-validating GaussianProcessSk...
# autoemulate - Parameters: {'alpha': 0.005488825696304717, 'copy_X_train': True, 'kernel__length_scale': 1.0, 'kernel__alpha': 1.0, 'kernel__length_scale_bounds': (1e-05, 100000.0), 'kernel__alpha_bounds': (1e-05, 100000.0), 'kernel': RationalQuadratic(alpha=1, length_scale=1), 'n_restarts_optimizer': 20, 'normalize_y': True, 'optimizer': 'fmin_l_bfgs_b', 'random_state': None}
# autoemulate - Performing grid search for SupportVectorMachines...
# autoemulate - Best parameters for SupportVectorMachines: {'model__estimator__C': 1.6095288186497414, 'model__estimator__cache_size': 252, 'model__estimator__coef0': 0.07183562505782193, 'model__estimator__degree': 3, 'model__estimator__epsilon': 0.1578230471402401, 'model__estimator__gamma': 'scale', 'model__estimator__kernel': 'linear', 'model__estimator__max_iter': -1, 'model__estimator__shrinking': False, 'model__estimator__tol': 0.0005403378399111992, 'model__estimator__verbose': False}
# autoemulate - Cross-validating SupportVectorMachines...
# autoemulate - Parameters: {'estimator__C': 1.6095288186497414, 'estimator__cache_size': 252, 'estimator__coef0': 0.07183562505782193, 'estimator__degree': 3, 'estimator__epsilon': 0.1578230471402401, 'estimator__gamma': 'scale', 'estimator__kernel': 'linear', 'estimator__max_iter': -1, 'estimator__normalise_y': True, 'estimator__shrinking': False, 'estimator__tol': 0.0005403378399111992, 'estimator__verbose': False, 'estimator': SupportVectorMachines(C=1.6095288186497414, cache_size=252,
#                       coef0=0.07183562505782193, epsilon=0.1578230471402401,
#                       kernel='linear', shrinking=False,
#                       tol=0.0005403378399111992), 'n_jobs': None}
# autoemulate - Performing grid search for NeuralNetSk...
# autoemulate - Best parameters for NeuralNetSk: {'model__activation': 'relu', 'model__alpha': 0.013648656791968854, 'model__hidden_layer_sizes': (50,), 'model__learning_rate_init': 0.00011128677145825468, 'model__solver': 'lbfgs'}
# autoemulate - Cross-validating NeuralNetSk...
# autoemulate - Parameters: {'activation': 'relu', 'alpha': 0.013648656791968854, 'hidden_layer_sizes': (50,), 'learning_rate': 'constant', 'learning_rate_init': 0.00011128677145825468, 'max_iter': 200, 'random_state': None, 'solver': 'lbfgs', 'tol': 0.0001}
# autoemulate - RBF is the best model with r2 = 0.863.
# autoemulate - Performing grid search for SecondOrderPolynomial...
# autoemulate - Best parameters for SecondOrderPolynomial: {}
# autoemulate - Cross-validating SecondOrderPolynomial...
# autoemulate - Parameters: {'degree': 2}
# autoemulate - Performing grid search for RBF...
# autoemulate - Best parameters for RBF: {'model__degree': 2, 'model__kernel': 'thin_plate_spline', 'model__smoothing': 0.7877034515689707}
# autoemulate - Cross-validating RBF...
# autoemulate - Parameters: {'degree': 2, 'epsilon': 1.0, 'kernel': 'thin_plate_spline', 'smoothing': 0.7877034515689707}
# autoemulate - Performing grid search for RandomForest...
# Run AutoEmulate on ../data/cardiac/cardiac7/processed
# autoemulate - Best parameters for RandomForest: {'model__bootstrap': False, 'model__max_features': 'sqrt', 'model__max_samples': 0.75, 'model__min_samples_leaf': 4, 'model__min_samples_split': 2, 'model__n_estimators': 417, 'model__oob_score': True}
# autoemulate - Cross-validating RandomForest...
# autoemulate - Parameters: {'bootstrap': False, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 'sqrt', 'max_samples': 0.75, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 417, 'oob_score': True, 'random_state': None}
# autoemulate - Performing grid search for GradientBoosting...
# autoemulate - Best parameters for GradientBoosting: {'model__estimator__ccp_alpha': 0.0949026585490058, 'model__estimator__learning_rate': 0.07493506995302532, 'model__estimator__max_depth': 3, 'model__estimator__max_features': None, 'model__estimator__min_samples_leaf': 1, 'model__estimator__min_samples_split': 19, 'model__estimator__n_estimators': 224, 'model__estimator__subsample': 0.884153758190797}
# autoemulate - Cross-validating GradientBoosting...
# autoemulate - Parameters: {'estimator__ccp_alpha': 0.0949026585490058, 'estimator__learning_rate': 0.07493506995302532, 'estimator__loss': 'squared_error', 'estimator__max_depth': 3, 'estimator__max_features': None, 'estimator__min_samples_leaf': 1, 'estimator__min_samples_split': 19, 'estimator__n_estimators': 224, 'estimator__n_iter_no_change': None, 'estimator__random_state': None, 'estimator__subsample': 0.884153758190797, 'estimator': GradientBoosting(ccp_alpha=0.0949026585490058,
#                  learning_rate=0.07493506995302532, min_samples_split=19,
#                  n_estimators=224, subsample=0.884153758190797), 'n_jobs': None}
# autoemulate - Performing grid search for GaussianProcessSk...
# autoemulate - Best parameters for GaussianProcessSk: {'model__alpha': 3.74308183882037e-09, 'model__kernel': Matern(length_scale=1, nu=1.5), 'model__normalize_y': True, 'model__optimizer': 'fmin_l_bfgs_b'}
# autoemulate - Cross-validating GaussianProcessSk...
# autoemulate - Parameters: {'alpha': 3.74308183882037e-09, 'copy_X_train': True, 'kernel__length_scale': 1.0, 'kernel__length_scale_bounds': (1e-05, 100000.0), 'kernel__nu': 1.5, 'kernel': Matern(length_scale=1, nu=1.5), 'n_restarts_optimizer': 20, 'normalize_y': True, 'optimizer': 'fmin_l_bfgs_b', 'random_state': None}
# autoemulate - Performing grid search for SupportVectorMachines...
# autoemulate - Best parameters for SupportVectorMachines: {'model__estimator__C': 3.9730326322077105, 'model__estimator__cache_size': 387, 'model__estimator__coef0': 0.5185786693673089, 'model__estimator__degree': 2, 'model__estimator__epsilon': 0.27920948973960397, 'model__estimator__gamma': 'scale', 'model__estimator__kernel': 'poly', 'model__estimator__max_iter': -1, 'model__estimator__shrinking': False, 'model__estimator__tol': 0.0009249259001285711, 'model__estimator__verbose': False}
# autoemulate - Cross-validating SupportVectorMachines...
# autoemulate - Parameters: {'estimator__C': 3.9730326322077105, 'estimator__cache_size': 387, 'estimator__coef0': 0.5185786693673089, 'estimator__degree': 2, 'estimator__epsilon': 0.27920948973960397, 'estimator__gamma': 'scale', 'estimator__kernel': 'poly', 'estimator__max_iter': -1, 'estimator__normalise_y': True, 'estimator__shrinking': False, 'estimator__tol': 0.0009249259001285711, 'estimator__verbose': False, 'estimator': SupportVectorMachines(C=3.9730326322077105, cache_size=387,
#                       coef0=0.5185786693673089, degree=2,
#                       epsilon=0.27920948973960397, kernel='poly',
#                       shrinking=False, tol=0.0009249259001285711), 'n_jobs': None}
# autoemulate - Performing grid search for NeuralNetSk...
# autoemulate - Best parameters for NeuralNetSk: {'model__activation': 'relu', 'model__alpha': 0.016254875849080107, 'model__hidden_layer_sizes': (50,), 'model__learning_rate_init': 0.003019000791920218, 'model__solver': 'lbfgs'}
# autoemulate - Cross-validating NeuralNetSk...
# autoemulate - Parameters: {'activation': 'relu', 'alpha': 0.016254875849080107, 'hidden_layer_sizes': (50,), 'learning_rate': 'constant', 'learning_rate_init': 0.003019000791920218, 'max_iter': 200, 'random_state': None, 'solver': 'lbfgs', 'tol': 0.0001}
# autoemulate - RBF is the best model with r2 = 0.942.
# autoemulate - Performing grid search for SecondOrderPolynomial...
# autoemulate - Best parameters for SecondOrderPolynomial: {}
# autoemulate - Cross-validating SecondOrderPolynomial...
# autoemulate - Parameters: {'degree': 2}
# autoemulate - Performing grid search for RBF...
# autoemulate - Best parameters for RBF: {'model__degree': 2, 'model__kernel': 'cubic', 'model__smoothing': 0.05961182328680392}
# autoemulate - Cross-validating RBF...
# autoemulate - Parameters: {'degree': 2, 'epsilon': 1.0, 'kernel': 'cubic', 'smoothing': 0.05961182328680392}
# autoemulate - Performing grid search for RandomForest...
# Run AutoEmulate on ../data/cardiac/cardiac8/processed
# autoemulate - Best parameters for RandomForest: {'model__bootstrap': False, 'model__max_features': 'log2', 'model__max_samples': 0.75, 'model__min_samples_leaf': 2, 'model__min_samples_split': 7, 'model__n_estimators': 358, 'model__oob_score': False}
# autoemulate - Cross-validating RandomForest...
# autoemulate - Parameters: {'bootstrap': False, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 'log2', 'max_samples': 0.75, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 358, 'oob_score': False, 'random_state': None}
# autoemulate - Performing grid search for GradientBoosting...
# autoemulate - Best parameters for GradientBoosting: {'model__estimator__ccp_alpha': 0.04751804579568181, 'model__estimator__learning_rate': 0.1302476282047804, 'model__estimator__max_depth': 5, 'model__estimator__max_features': None, 'model__estimator__min_samples_leaf': 3, 'model__estimator__min_samples_split': 9, 'model__estimator__n_estimators': 482, 'model__estimator__subsample': 0.6174631415261757}
# autoemulate - Cross-validating GradientBoosting...
# autoemulate - Parameters: {'estimator__ccp_alpha': 0.04751804579568181, 'estimator__learning_rate': 0.1302476282047804, 'estimator__loss': 'squared_error', 'estimator__max_depth': 5, 'estimator__max_features': None, 'estimator__min_samples_leaf': 3, 'estimator__min_samples_split': 9, 'estimator__n_estimators': 482, 'estimator__n_iter_no_change': None, 'estimator__random_state': None, 'estimator__subsample': 0.6174631415261757, 'estimator': GradientBoosting(ccp_alpha=0.04751804579568181,
#                  learning_rate=0.1302476282047804, max_depth=5,
#                  min_samples_leaf=3, min_samples_split=9, n_estimators=482,
#                  subsample=0.6174631415261757), 'n_jobs': None}
# autoemulate - Performing grid search for GaussianProcessSk...
# autoemulate - Best parameters for GaussianProcessSk: {'model__alpha': 1.6400470336037916e-10, 'model__kernel': RationalQuadratic(alpha=1, length_scale=1), 'model__normalize_y': True, 'model__optimizer': 'fmin_l_bfgs_b'}
# autoemulate - Cross-validating GaussianProcessSk...
# autoemulate - Parameters: {'alpha': 1.6400470336037916e-10, 'copy_X_train': True, 'kernel__length_scale': 1.0, 'kernel__alpha': 1.0, 'kernel__length_scale_bounds': (1e-05, 100000.0), 'kernel__alpha_bounds': (1e-05, 100000.0), 'kernel': RationalQuadratic(alpha=1, length_scale=1), 'n_restarts_optimizer': 20, 'normalize_y': True, 'optimizer': 'fmin_l_bfgs_b', 'random_state': None}
# autoemulate - Performing grid search for SupportVectorMachines...
# autoemulate - Best parameters for SupportVectorMachines: {'model__estimator__C': 3.4228357181531117, 'model__estimator__cache_size': 308, 'model__estimator__coef0': 0.2618372893172759, 'model__estimator__degree': 3, 'model__estimator__epsilon': 0.14006780258531315, 'model__estimator__gamma': 'scale', 'model__estimator__kernel': 'poly', 'model__estimator__max_iter': -1, 'model__estimator__shrinking': False, 'model__estimator__tol': 0.0008039556362356082, 'model__estimator__verbose': False}
# autoemulate - Cross-validating SupportVectorMachines...
# autoemulate - Parameters: {'estimator__C': 3.4228357181531117, 'estimator__cache_size': 308, 'estimator__coef0': 0.2618372893172759, 'estimator__degree': 3, 'estimator__epsilon': 0.14006780258531315, 'estimator__gamma': 'scale', 'estimator__kernel': 'poly', 'estimator__max_iter': -1, 'estimator__normalise_y': True, 'estimator__shrinking': False, 'estimator__tol': 0.0008039556362356082, 'estimator__verbose': False, 'estimator': SupportVectorMachines(C=3.4228357181531117, cache_size=308,
#                       coef0=0.2618372893172759, epsilon=0.14006780258531315,
#                       kernel='poly', shrinking=False,
#                       tol=0.0008039556362356082), 'n_jobs': None}
# autoemulate - Performing grid search for NeuralNetSk...
# autoemulate - Best parameters for NeuralNetSk: {'model__activation': 'relu', 'model__alpha': 8.608016703659104e-05, 'model__hidden_layer_sizes': (100, 50), 'model__learning_rate_init': 0.006250645955867938, 'model__solver': 'lbfgs'}
# autoemulate - Cross-validating NeuralNetSk...
# autoemulate - Parameters: {'activation': 'relu', 'alpha': 8.608016703659104e-05, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'learning_rate_init': 0.006250645955867938, 'max_iter': 200, 'random_state': None, 'solver': 'lbfgs', 'tol': 0.0001}
# autoemulate - NeuralNetSk is the best model with r2 = 0.994.

# %%
results_df
# Out:
#                     model metric  fold     score  \
# 0   SecondOrderPolynomial   rsme     0  1.214096
# 1   SecondOrderPolynomial   rsme     1  1.834830
# 2   SecondOrderPolynomial   rsme     2  1.210832
# 3   SecondOrderPolynomial   rsme     3  1.204286
# 4   SecondOrderPolynomial   rsme     4  1.354231
# ..                    ...    ...   ...       ...
# 75            NeuralNetSk     r2     0  0.156044
# 76            NeuralNetSk     r2     1 -0.005696
# 77            NeuralNetSk     r2     2 -0.015550
# 78            NeuralNetSk     r2     3  0.021491
# 79            NeuralNetSk     r2     4  0.222311
#
#                                   path             best_model
# 0   ../data/cardiac/cardiac1/processed                    RBF
# 1   ../data/cardiac/cardiac1/processed                    RBF
# 2   ../data/cardiac/cardiac1/processed                    RBF
# 3   ../data/cardiac/cardiac1/processed                    RBF
# 4   ../data/cardiac/cardiac1/processed                    RBF
# ..                                 ...                    ...
# 75  ../data/cardiac/cardiac2/processed  SecondOrderPolynomial
# 76  ../data/cardiac/cardiac2/processed  SecondOrderPolynomial
# 77  ../data/cardiac/cardiac2/processed  SecondOrderPolynomial
# 78  ../data/cardiac/cardiac2/processed  SecondOrderPolynomial
# 79  ../data/cardiac/cardiac2/processed  SecondOrderPolynomial
#
# [160 rows x 6 columns]

# %%
# mapping from cardiac to descriptive

cardiac_descriptions = {
    "cardiac1": "Atrial Ionic",
    "cardiac2": "Atrial Isotonic Contraction",
    "cardiac3": "Atrial Isometric Stretch 1.0",
    "cardiac4": "Atrial Isometric Stretch 1.1",
    "cardiac5": "CircAdap",
    "cardiac6": "Fourchamber Model",
    "cardiac7": "Passive Mechanics",
    "cardiac8": "Tissue Electrophysiology",
    "cardiac9": "Ventricular Ionic",
    "cardiac10": "Ventricular Isotonic Contraction",
    "cardiac11": "Ventricular Isometric Stretch 1.0",
    "cardiac12": "Ventricular Isometric Stretch 1.1"
}

# %%
(results_df
    # filter out mteric = rsme
    .query('metric != "rsme"')
    .groupby(['path', 'metric', 'model'])
    .agg({'score': ['mean', 'std']})
    # sort by mean score for each path
    .sort_values(by=['path', ('score', 'mean')], ascending=False)
    # sort path from cardiac1 to cardiac12
    .sort_index(level=0, sort_remaining=False)
    .reset_index()
    # Extract cardiac number and create a new column
    .assign(cardiac=lambda df: df['path'].str.extract('(cardiac\d+)')[0])
)
# Out:
#                                   path metric                  model  \
#
# 0   ../data/cardiac/cardiac1/processed     r2                    RBF
# 1   ../data/cardiac/cardiac1/processed     r2      GaussianProcessSk
# 2   ../data/cardiac/cardiac1/processed     r2  SecondOrderPolynomial
# 3   ../data/cardiac/cardiac1/processed     r2  SupportVectorMachines
# 4   ../data/cardiac/cardiac1/processed     r2       GradientBoosting
# 5   ../data/cardiac/cardiac1/processed     r2                XGBoost
# 6   ../data/cardiac/cardiac1/processed     r2           RandomForest
# 7   ../data/cardiac/cardiac1/processed     r2            NeuralNetSk
# 8   ../data/cardiac/cardiac2/processed     r2  SecondOrderPolynomial
# 9   ../data/cardiac/cardiac2/processed     r2                    RBF
# 10  ../data/cardiac/cardiac2/processed     r2  SupportVectorMachines
# 11  ../data/cardiac/cardiac2/processed     r2       GradientBoosting
# 12  ../data/cardiac/cardiac2/processed     r2                XGBoost
# 13  ../data/cardiac/cardiac2/processed     r2      GaussianProcessSk
# 14  ../data/cardiac/cardiac2/processed     r2           RandomForest
# 15  ../data/cardiac/cardiac2/processed     r2            NeuralNetSk
#
#          score              cardiac
#           mean        std
# 0     0.994564   0.001094  cardiac1
# 1     0.994522   0.000366  cardiac1
# 2     0.994057   0.001043  cardiac1
# 3     0.952853   0.008369  cardiac1
# 4     0.920941   0.006775  cardiac1
# 5     0.891877   0.015081  cardiac1
# 6     0.655266   0.018354  cardiac1
# 7  -156.020665  39.703207  cardiac1
# 8     0.834925   0.010954  cardiac2
# 9     0.818380   0.014362  cardiac2
# 10    0.753703   0.005290  cardiac2
# 11    0.661940   0.015846  cardiac2
# 12    0.650019   0.009549  cardiac2
# 13    0.453594   0.361179  cardiac2
# 14    0.420178   0.012334  cardiac2
# 15    0.075720   0.107052  cardiac2

# %%
# Out:
# {'RBF':                     model metric  fold       score
#  0   SecondOrderPolynomial   rsme     0    1.658468
#  1   SecondOrderPolynomial   rsme     1    1.550802
#  2   SecondOrderPolynomial   rsme     2    1.276326
#  3   SecondOrderPolynomial   rsme     3    1.059498
#  4   SecondOrderPolynomial   rsme     4    1.224820
#  ..                    ...    ...   ...         ...
#  75            NeuralNetSk     r2     0 -110.597701
#  76            NeuralNetSk     r2     1 -118.794065
#  77            NeuralNetSk     r2     2 -127.591954
#  78            NeuralNetSk     r2     3 -155.855949
#  79            NeuralNetSk     r2     4 -184.621297
#
#  [80 rows x 4 columns]}

# %%
# load csv as numpy array
X,y = fetch_data(path/'cardiac/cardiac1/processed')

# %%
em = AutoEmulate()
em.setup(X, y, n_jobs=-1, grid_search_iters=50, folds=5, grid_search_type='random')
em.compare()
# Out:
# autoemulate - Cross-validating SecondOrderPolynomial...
# autoemulate - Parameters: {'degree': 2}
# autoemulate - Cross-validating RBF...
# autoemulate - Parameters: {'degree': 1, 'epsilon': 1.0, 'kernel': 'thin_plate_spline', 'smoothing': 0.0}
# autoemulate - Cross-validating RandomForest...
# autoemulate - Parameters: {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_samples': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100, 'oob_score': False, 'random_state': None}
# autoemulate - Cross-validating GradientBoosting...
# autoemulate - Parameters: {'estimator__ccp_alpha': 0.0, 'estimator__learning_rate': 0.1, 'estimator__loss': 'squared_error', 'estimator__max_depth': 3, 'estimator__max_features': None, 'estimator__min_samples_leaf': 1, 'estimator__min_samples_split': 2, 'estimator__n_estimators': 100, 'estimator__n_iter_no_change': None, 'estimator__random_state': None, 'estimator__subsample': 1.0, 'estimator': GradientBoosting(), 'n_jobs': None}
# autoemulate - Cross-validating GaussianProcessSk...
# autoemulate - Parameters: {'alpha': 1e-10, 'copy_X_train': True, 'kernel__length_scale': 1.0, 'kernel__length_scale_bounds': (1e-05, 100000.0), 'kernel': RBF(length_scale=1), 'n_restarts_optimizer': 20, 'normalize_y': True, 'optimizer': 'fmin_l_bfgs_b', 'random_state': None}
# autoemulate - Cross-validating SupportVectorMachines...
# autoemulate - Parameters: {'estimator__C': 1.0, 'estimator__cache_size': 200, 'estimator__coef0': 0.0, 'estimator__degree': 3, 'estimator__epsilon': 0.1, 'estimator__gamma': 'scale', 'estimator__kernel': 'rbf', 'estimator__max_iter': -1, 'estimator__normalise_y': True, 'estimator__shrinking': True, 'estimator__tol': 0.001, 'estimator__verbose': False, 'estimator': SupportVectorMachines(), 'n_jobs': None}
# autoemulate - Cross-validating XGBoost...
# autoemulate - Parameters: {'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 1, 'gamma': 0, 'learning_rate': 0.3, 'max_delta_step': 0, 'max_depth': 6, 'max_leaves': 0, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': None, 'objective': 'reg:squarederror', 'random_state': None, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 1, 'tree_method': 'auto', 'verbosity': 0}
# autoemulate - Cross-validating NeuralNetSk...
# autoemulate - Parameters: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_iter': 200, 'random_state': None, 'solver': 'adam', 'tol': 0.0001}
# autoemulate - RBF is the best model with r2 = 0.994.
# Pipeline(steps=[('scaler', StandardScaler()), ('model', RBF())])

# %%
em.scores_df
# Out:
#                     model metric  fold       score
# 0   SecondOrderPolynomial   rsme     0    1.148593
# 1   SecondOrderPolynomial   rsme     1    2.113252
# 2   SecondOrderPolynomial   rsme     2    1.335141
# 3   SecondOrderPolynomial   rsme     3    1.041811
# 4   SecondOrderPolynomial   rsme     4    1.229983
# ..                    ...    ...   ...         ...
# 75            NeuralNetSk     r2     0 -125.558727
# 76            NeuralNetSk     r2     1 -113.039760
# 77            NeuralNetSk     r2     2 -108.484559
# 78            NeuralNetSk     r2     3 -148.870362
# 79            NeuralNetSk     r2     4 -137.387880
#
# [80 rows x 4 columns]
